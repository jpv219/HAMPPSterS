# %%
import pandas as pd
import glob
import sys
import csv
import os
import numpy as np
import math

import matplotlib.pyplot as plt
import matplotlib.pylab as pl
from matplotlib import rc
import seaborn as sns

# For fitting test #
from scipy import stats
# import statsmodels.api as sm
import pylab as py
import ast

import matplotlib as mpl
mpl.rcParams['axes.linewidth'] = 3 #set the value globally
from matplotlib.ticker import FormatStrFormatter
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ['Times']})

# %%
csv_path = '/home/fl18/Desktop/automatework/ML_auto/SMX_DeepLearning/Database-ActiveLearning/CSV_BKP/finished_sp_svgeom'
csv_file = os.path.join(csv_path, 'sp_svgeom_1.csv')
data = pd.read_csv(csv_file)

columns = ['Height', 'Q', 'Pres', 'Ur', 'Uth', 'Uz', 'arc_length',
       'Q_over_line', 'Ur_over_line', 'Uz_over_line']
Vels = ['Ur', 'Uth', 'Uz','Ur_over_line', 'Uz_over_line']
for column in columns:
    data[column] = data[column].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
    if column in Vels:
        v_tip =  
        data[column] = data[column] * math(pi)

print(data.columns)
print(data['Run'][0])
# Out:
# Index(['Run', 'Time', 'Height', 'Q', 'Pres', 'Ur', 'Uth', 'Uz', 'arc_length',
#        'Q_over_line', 'Ur_over_line', 'Uz_over_line'],
#       dtype='object')
# run_spsv_2

# %%
fig, axes = plt.subplots(1,4,figsize=(20,8),sharey=True)
for i in range(len(data)):
    axes[0].plot(data['Q'][i], data['Height'][i])#,label=r'str(data[0][i])')
    axes[1].plot(data['Pres'][i], data['Height'][i])#,label=f'{data['Run'][i]}')
    axes[2].plot(data['Ur'][i], data['Height'][i])#,label=f'{data['Run'][i]}')
    axes[3].plot(data['Uz'][i], data['Height'][i])#,label=f'{data['Run'][i]}')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
fig, axes = plt.subplots(3,1,figsize=(8,15),sharex=True)
for i in range(len(data)):
    axes[0].plot(data['arc_length'][i], data['Q_over_line'][i])#,label=r'str(data[0][i])')
    axes[1].plot(data['arc_length'][i], data['Ur_over_line'][i])#,label=f'{data['Run'][i]}')
    axes[2].plot(data['arc_length'][i], data['Uz_over_line'][i])#,label=f'{data['Run'][i]}')
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
